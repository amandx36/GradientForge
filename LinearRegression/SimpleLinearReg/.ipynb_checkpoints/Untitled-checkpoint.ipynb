# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
doc = pd.read_csv("./placement.csv")
# !ls

# %%
doc.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %% [markdown]
# # Plotting the graph

# %% [raw]
# plt.x
